# %% [markdown]
# # Matplotlib 실습
# 먼저 matplotlib.pyplot을 import한다. 실습에 필요한 numpy도 import한다.
# jupyter notebook에서 plot이 바로 표시 될 수 있도록 매직 명령어를 사용한다.
# > %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# 간단히 다음과 같은 sine 함수 그래프와 cosine함수 그래프를 그려보자.

# %%
x = np.linspace(0,10,100)

plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# subplot 기능을 활용하여 sine함수와 cosine함수 그래프를 다음과 같이 그려보자

# %%
plt.figure()

plt.subplot(2,1,1)
plt.plot(x, np.sin(x))

plt.subplot(212)
plt.plot(x, np.cos(x))

# %% [markdown]
# 플롯의 선 색상과 스타일을 다음과 같이 바꾸어서 그려보자.
# - color : r,g,b,c,y,m,k,w
# - linestyle : -, --, :, o, ^

# %%
plt.plot(x)

# %%
plt.plot(x, 'r-')
plt.plot(x+1, 'g--')
plt.plot(x+2, 'b:')
plt.plot(x+3, 'y-.')

# %% [markdown]
# plt.xlim()과 plt.ylim() 을 사용하여 x축과 y축을 제한 할 수 있다.
# sine 그래프를 그리고 x축을 -1 ~ 11로 하고 y축을 -1.5 ~ 1.5로 나타내 보자.

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# x축과 y축의 비율을 동일하게 맞출 수 있다.

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0993384025373631, 1.0996461858110391)

# %% [markdown]
# x축과 y축에 label을 추가하고 그래프의 제목을 추가한다.

# %%
plt.plot(x, np.sin(x))
plt.title('Sine Curve')
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# Legend의 표시
# 각 그래프 선에 대해서 label을 붙이고 그래프에서 legend로 표시한다.
# legend loc 옵션 : 'upper right', 'upper left', 'lower left','lower right' 등으로 위치 지정 가능하다.

# %%
plt.subplot(2,1,1)
plt.plot(x, np.sin(x), '-g', label ='sin(x)')
plt.legend(loc='lower left')
plt.subplot(2,1,2)
plt.plot(x, np.cos(x), ':b', label ='cos(x)')
plt.legend()

# %% [markdown]
# 산점도 그리기

# %%
x = np.random.randint(1,10,15)
y = np.random.randint(1,10,15)

plt.plot(x, y,'o')

# %%
size = np.random.randint(1,500,10)
color =  np.random.randint(1,100,15)
plt.scatter(x,y, s=size, c=color)

# %% [markdown]
# 히스토그램
# hist()함수를 사용해서 히스토그램을 그려 데이터 분포를 확인할 수 있다.
# 여러가지 option으로 조정 가능하다.

# %%
data = np.random.randn(1000)
plt.hist(data)
# Out:
# (array([ 13.,  51., 129., 227., 266., 186.,  98.,  27.,   2.,   1.]),
#  array([-2.86021415, -2.19133539, -1.52245662, -0.85357786, -0.1846991 ,
#          0.48417966,  1.15305842,  1.82193718,  2.49081594,  3.15969471,
#          3.82857347]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data, bins=30, color='red')
# Out:
# (array([ 2.,  5.,  6., 17., 10., 24., 36., 40., 53., 72., 68., 87., 91.,
#         84., 91., 67., 64., 55., 46., 34., 18., 15.,  6.,  6.,  1.,  0.,
#          1.,  0.,  0.,  1.]),
#  array([-2.86021415, -2.63725456, -2.41429497, -2.19133539, -1.9683758 ,
#         -1.74541621, -1.52245662, -1.29949704, -1.07653745, -0.85357786,
#         -0.63061828, -0.40765869, -0.1846991 ,  0.03826049,  0.26122007,
#          0.48417966,  0.70713925,  0.93009883,  1.15305842,  1.37601801,
#          1.5989776 ,  1.82193718,  2.04489677,  2.26785636,  2.49081594,
#          2.71377553,  2.93673512,  3.15969471,  3.38265429,  3.60561388,
#          3.82857347]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# 막대 그래프
# 요일별 판매량을 막대그래프로 나타내 보자.

# %%
day = ['MON','TUE','WED','THU','FRI']
y_val = [20, 100, 35, 40, 65]

plt.bar(day, y_val, ax)
# Out:
# <BarContainer object of 5 artists>
